# %%
# Group by function and getgroup

# %%
import pandas as pd

# %%
df = pd.read_excel('C:/Users/KAMPLI ENTERPRISES/PycharmProjects/Files/Orders.xlsx')

# %%
df
# Out:
#    Order ID Order Date  Order Quantity      Sales       Ship Mode    Profit  \
# 0         3 2010-10-13               6   261.5400     Regular Air  -213.250
# 1         6 2012-02-20               2     6.9300     Regular Air    -4.640
# 2        32 2011-07-15              26  2808.0800     Regular Air  1054.820
# 3        32 2011-07-15              24  1761.4000  Delivery Truck -1748.560
# 4        32 2011-07-15              23   160.2335     Regular Air   -85.129
# 5        32 2011-07-15              15   140.5600     Regular Air  -128.380
# 6        35 2011-10-22              30   288.5600     Regular Air    60.720
# 7        35 2011-10-22              14  1892.8480     Regular Air    48.987
# 8        36 2011-11-02              46  2484.7455     Regular Air   657.477
# 9        65 2011-03-17              32  3812.7300     Regular Air  1470.300
#
#    Unit Price       Customer Name Customer Segment Product Category
# ...

# %%
# Select cust seg, count(*) frm Orders group by Cust segment

g = df.groupby('Customer Segment')

# %%
g

# %%
g['Customer Segment'] . count()
# Out:
# Customer Segment
# Corporate         8
# Home Office       1
# Small Business    1
# Name: Customer Segment, dtype: int64

# %%
# Group on multiple columns
g1 = df.groupby(['Customer Segment','Product Category'])

# %%
g1[['Customer Segment','Product Category']] . count()
# Out:
#                                    Customer Segment  Product Category
# Customer Segment Product Category
# Corporate        Furniture                        2                 2
#                  Office Supplies                  2                 2
#                  Technology                       4                 4
# Home Office      Technology                       1                 1
# Small Business   Office Supplies                  1                 1

# %%
# Get values of specific values in col
g2 = df.groupby(['Customer Segment'])

# %%
g2.get_group('Home Office')
# Out:
# C:\Users\KAMPLI ENTERPRISES\AppData\Local\Temp\ipykernel_36696\515705247.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   g2.get_group('Home Office')
#    Order ID Order Date  Order Quantity      Sales    Ship Mode   Profit  \
# 8        36 2011-11-02              46  2484.7455  Regular Air  657.477
#
#    Unit Price     Customer Name Customer Segment Product Category
# 8       65.99  Sample Company A      Home Office       Technology

# %%
g3 = df.groupby(['Product Category'])

# %%
g3.get_group('Technology')
# Out:
# C:\Users\KAMPLI ENTERPRISES\AppData\Local\Temp\ipykernel_36696\1715899608.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   g3.get_group('Technology')
#    Order ID Order Date  Order Quantity      Sales    Ship Mode    Profit  \
# 4        32 2011-07-15              23   160.2335  Regular Air   -85.129
# 5        32 2011-07-15              15   140.5600  Regular Air  -128.380
# 7        35 2011-10-22              14  1892.8480  Regular Air    48.987
# 8        36 2011-11-02              46  2484.7455  Regular Air   657.477
# 9        65 2011-03-17              32  3812.7300  Regular Air  1470.300
#
#    Unit Price     Customer Name Customer Segment Product Category
# 4        7.99     Liz Pelletier        Corporate       Technology
# 5        8.46     Liz Pelletier        Corporate       Technology
# ...
