# %%
# imprt Pandas library
import pandas as pd

# %%
# Define variable and use read_csv func to read csv file
df = pd.read_csv('E:/Python/MyPython/PycharmProjects/MyLearnings1/ETLQASession/TestFiles/ind_nifty50list.csv')

# %%
# display the values
df
# Out:
#                                   Company Name  \
# 0                       Adani Enterprises Ltd.
# 1   Adani Ports and Special Economic Zone Ltd.
# 2             Apollo Hospitals Enterprise Ltd.
# 3                            Asian Paints Ltd.
# 4                               Axis Bank Ltd.
# 5                              Bajaj Auto Ltd.
# 6                           Bajaj Finance Ltd.
# 7                           Bajaj Finserv Ltd.
# 8                      Bharat Electronics Ltd.
# 9                           Bharti Airtel Ltd.
# 10                                  Cipla Ltd.
# 11                             Coal India Ltd.
# 12               Dr. Reddy's Laboratories Ltd.
# 13                          Eicher Motors Ltd.
# 14                                Eternal Ltd.
# 15                      Grasim Industries Ltd.
# 16                       HCL Technologies Ltd.
# 17                              HDFC Bank Ltd.
# 18            HDFC Life Insurance Company Ltd.
# ...

# %%
# Check data type
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Display specific columns using list
df[['Company Name','Industry','Symbol']]
# Out:
#                                   Company Name  \
# 0                       Adani Enterprises Ltd.
# 1   Adani Ports and Special Economic Zone Ltd.
# 2             Apollo Hospitals Enterprise Ltd.
# 3                            Asian Paints Ltd.
# 4                               Axis Bank Ltd.
# 5                              Bajaj Auto Ltd.
# 6                           Bajaj Finance Ltd.
# 7                           Bajaj Finserv Ltd.
# 8                      Bharat Electronics Ltd.
# 9                           Bharti Airtel Ltd.
# 10                                  Cipla Ltd.
# 11                             Coal India Ltd.
# 12               Dr. Reddy's Laboratories Ltd.
# 13                          Eicher Motors Ltd.
# 14                                Eternal Ltd.
# 15                      Grasim Industries Ltd.
# 16                       HCL Technologies Ltd.
# 17                              HDFC Bank Ltd.
# 18            HDFC Life Insurance Company Ltd.
# ...

# %%
# Check type for only one column
type(df['Industry'])
# Out:
# pandas.core.series.Series

# %%
# Shape func gives no. of rows and column
df.shape
# Out:
# (50, 5)

# %%
# Info func gives data structure details
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company Name  50 non-null     object
#  1   Industry      50 non-null     object
#  2   Symbol        50 non-null     object
#  3   Series        50 non-null     object
#  4   ISIN Code     50 non-null     object
# dtypes: object(5)
# memory usage: 2.1+ KB

# %%
# Head func display top n row
df.head(5)
# Out:
#                                  Company Name            Industry      Symbol  \
# 0                      Adani Enterprises Ltd.     Metals & Mining    ADANIENT
# 1  Adani Ports and Special Economic Zone Ltd.            Services  ADANIPORTS
# 2            Apollo Hospitals Enterprise Ltd.          Healthcare  APOLLOHOSP
# 3                           Asian Paints Ltd.   Consumer Durables  ASIANPAINT
# 4                              Axis Bank Ltd.  Financial Services    AXISBANK
#
#   Series     ISIN Code
# 0     EQ  INE423A01024
# 1     EQ  INE742F01042
# 2     EQ  INE437A01024
# 3     EQ  INE021A01026
# 4     EQ  INE238A01034

# %%
# Tail func displays bottom n rows
df.tail(5)
# Out:
#              Company Name                Industry      Symbol Series  \
# 45     Tech Mahindra Ltd.  Information Technology       TECHM     EQ
# 46     Titan Company Ltd.       Consumer Durables       TITAN     EQ
# 47             Trent Ltd.       Consumer Services       TRENT     EQ
# 48  UltraTech Cement Ltd.  Construction Materials  ULTRACEMCO     EQ
# 49             Wipro Ltd.  Information Technology       WIPRO     EQ
#
#        ISIN Code
# 45  INE669C01036
# 46  INE280A01028
# 47  INE849A01020
# 48  INE481G01011
# 49  INE075A01022
