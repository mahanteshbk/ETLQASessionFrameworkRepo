# %%
# Read different types of files csvdata,tsv,excel,json

# %%
import pandas as pd

# %%
# Read csv via read_csv
csvdata = pd.read_csv('E:/Python/MyPython/PycharmProjects/MyLearnings1/ETLQASession/TestFiles/04_products.csv')

# %%
csvdata
# Out:
#                                      Name  \
# 0    Compact Printer Air Advanced Digital
# 1                                  Tablet
# 2                    Smart Blender Cooker
# 3            Advanced Router Rechargeable
# 4            Portable Mouse Monitor Phone
# ..                                    ...
# 95                                 Router
# 96     Fast Thermostat Microphone Scooter
# 97  Eco Heater Toaster Stove Silent Sense
# 98               Clean Blender Scale Lite
# 99                             Smart Lamp
#
#                                           Description  \
# 0       Situation organization these memory much off.
# 1         Discussion loss politics free one thousand.
# 2                                   No situation per.
# 3                     For force gas energy six laugh.
# 4   Feeling back religious however author room sci...
# ..                                                ...
# 95                   Investment everything story buy.
# ...

# %%
# Read text file with commas via read_csv
txtcomdata = pd.read_csv('E:/Python/MyPython/PycharmProjects/MyLearnings1/ETLQASession/TestFiles/04_products_comma.txt')

# %%
txtcomdata
# Out:
#                                                                                    Name  \
# Compact Printer Air Advanced Digital      Situation organization these memory much off.
# Tablet                                      Discussion loss politics free one thousand.
# Smart Blender Cooker                                                  No situation per.
# Advanced Router Rechargeable                            For force gas energy six laugh.
# Portable Mouse Monitor Phone          Feeling back religious however author room sci...
#
#                                              Description                Brand  \
# Compact Printer Air Advanced Digital              Garner      Boyle and Flynn
# Tablet                                       Mueller Inc     Shoes & Footwear
# Smart Blender Cooker                              Lawson   Keller and Winters
# Advanced Router Rechargeable          Gallagher and Sons   Kitchen Appliances
# ...

# %%
# Read text file with semicolon via read_csv
txtsemidata = pd.read_csv('E:/Python/MyPython/PycharmProjects/MyLearnings1/ETLQASession/TestFiles/04_products_semi.txt')

# %%
txtsemidata
# Out:
#   Name;Description;Brand;Category;Price;Currency;Stock;EAN;Color;Size;Availability;Internal ID
# 0  Compact Printer Air Advanced Digital;Situation...
# 1  Tablet;Discussion loss politics free one thous...
# 2  Smart Blender Cooker;No situation per.;Lawson;...
# 3  Advanced Router Rechargeable;For force gas ene...
# 4  Portable Mouse Monitor Phone;Feeling back reli...

# %%
# Read text file with semicolon via read_csv by adding separator
txtsemidata = pd.read_csv('E:/Python/MyPython/PycharmProjects/MyLearnings1/ETLQASession/TestFiles/04_products_semi.txt',sep = ';')

# %%
txtsemidata
# Out:
#                                                                                    Name  \
# Compact Printer Air Advanced Digital      Situation organization these memory much off.
# Tablet                                      Discussion loss politics free one thousand.
# Smart Blender Cooker                                                  No situation per.
# Advanced Router Rechargeable                            For force gas energy six laugh.
# Portable Mouse Monitor Phone          Feeling back religious however author room sci...
#
#                                              Description                Brand  \
# Compact Printer Air Advanced Digital              Garner      Boyle and Flynn
# Tablet                                       Mueller Inc     Shoes & Footwear
# Smart Blender Cooker                              Lawson   Keller and Winters
# Advanced Router Rechargeable          Gallagher and Sons   Kitchen Appliances
# ...

# %%
# Read text file with tab via read_csv by adding separator
txttabdata = pd.read_csv('E:/Python/MyPython/PycharmProjects/MyLearnings1/ETLQASession/TestFiles/04_products_tab.txt',sep = '\t')

# %%
txttabdata
# Out:
#                                              Name  \
# 0            Compact Printer Air Advanced Digital
# 1                                          Tablet
# 2                            Smart Blender Cooker
# 3                    Advanced Router Rechargeable
# 4                    Portable Mouse Monitor Phone
# 5                                           Radio
# 6  Ultra Projector Oven Thermostat Prime Advanced
# 7                              Webcam Stove Grill
# 8                                       Eco Radio
#
#                                          Description  \
# 0      Situation organization these memory much off.
# 1        Discussion loss politics free one thousand.
# 2                                  No situation per.
# 3                    For force gas energy six laugh.
# 4  Feeling back religious however author room sci...
# 5   Character prove growth contain serious customer.
# 6  Pattern possible look necessary indicate work ...
# ...

# %%
txttabdata = pd.read_table('C:/Users/KAMPLI ENTERPRISES/PycharmProjects/Files/products_tab.txt', sep = '\t')

# %%
txttabdata
# Out:
#                                              Name  \
# 0            Compact Printer Air Advanced Digital
# 1                                          Tablet
# 2                            Smart Blender Cooker
# 3                    Advanced Router Rechargeable
# 4                    Portable Mouse Monitor Phone
# 5                                           Radio
# 6  Ultra Projector Oven Thermostat Prime Advanced
# 7                              Webcam Stove Grill
# 8                                       Eco Radio
#
#                                          Description  \
# 0      Situation organization these memory much off.
# 1        Discussion loss politics free one thousand.
# 2                                  No situation per.
# 3                    For force gas energy six laugh.
# 4  Feeling back religious however author room sci...
# 5   Character prove growth contain serious customer.
# 6  Pattern possible look necessary indicate work ...
# ...

# %%
# Read excel via read_exel
exceldata = pd.read_excel('E:/Python/MyPython/PycharmProjects/MyLearnings1/ETLQASession/TestFiles/04_Orders.xlsx')

# %%
exceldata
# Out:
#    Order ID Order Date  Order Quantity      Sales       Ship Mode    Profit  \
# 0         3 2010-10-13               6   261.5400     Regular Air  -213.250
# 1         6 2012-02-20               2     6.9300     Regular Air    -4.640
# 2        32 2011-07-15              26  2808.0800     Regular Air  1054.820
# 3        32 2011-07-15              24  1761.4000  Delivery Truck -1748.560
# 4        32 2011-07-15              23   160.2335     Regular Air   -85.129
# 5        32 2011-07-15              15   140.5600     Regular Air  -128.380
# 6        35 2011-10-22              30   288.5600     Regular Air    60.720
# 7        35 2011-10-22              14  1892.8480     Regular Air    48.987
# 8        36 2011-11-02              46  2484.7455     Regular Air   657.477
# 9        65 2011-03-17              32  3812.7300     Regular Air  1470.300
#
#    Unit Price       Customer Name Customer Segment Product Category
# ...

# %%
 #Read json file read_json
jsondata = pd.read_json('E:/Python/MyPython/PycharmProjects/MyLearnings1/ETLQASession/TestFiles/04_employeeData.json')

# %%
jsondata
# Out:
#                                             employees
# 0   {'id': 100, 'FIRST_NAME': 'Steven', 'LAST_NAME...
# 1   {'id': 101, 'FIRST_NAME': 'Neena', 'LAST_NAME'...
# 2   {'id': 102, 'FIRST_NAME': 'Lex', 'LAST_NAME': ...
# 3   {'id': 103, 'FIRST_NAME': 'Alexander', 'LAST_N...
# 4   {'id': 105, 'FIRST_NAME': 'David', 'LAST_NAME'...
# 5   {'id': 106, 'FIRST_NAME': 'Valli', 'LAST_NAME'...
# 6   {'id': 107, 'FIRST_NAME': 'Diana', 'LAST_NAME'...
# 7   {'id': 108, 'FIRST_NAME': 'Nancy', 'LAST_NAME'...
# 8   {'id': 109, 'FIRST_NAME': 'Daniel', 'LAST_NAME...
# 9   {'id': 110, 'FIRST_NAME': 'John', 'LAST_NAME':...
# 10  {'id': 111, 'FIRST_NAME': 'Ismael', 'LAST_NAME...
# 11  {'id': 112, 'FIRST_NAME': 'Jose Manuel', 'LAST...
# 12  {'id': 113, 'FIRST_NAME': 'Luis', 'LAST_NAME':...
# 13  {'id': 114, 'FIRST_NAME': 'Den', 'LAST_NAME': ...
# 14  {'id': 115, 'FIRST_NAME': 'Alexander', 'LAST_N...
# 15  {'id': 116, 'FIRST_NAME': 'Shelli', 'LAST_NAME...
# ...

# %%
# write json data to csv

# %%
jsondata = pd.read_json('E:/Python/MyPython/PycharmProjects/MyLearnings1/ETLQASession/TestFiles/04_employeeData.json')

# %%
jsondata.to_csv('E:/Python/MyPython/PycharmProjects/MyLearnings1/ETLQASession/OutputFiles/04_jsoncsvdata.csv')

# %%
# read tsv data without header

# %%
tsvdata = pd.read_table('E:/Python/MyPython/PycharmProjects/MyLearnings1/ETLQASession/TestFiles/04_people_tab.txt')

# %%
tsvdata
# Out:
#    88F7B33d2bcf9f5    Shelby   Terrell    Male        elijah57@example.net  \
# 0  f90cD3E76f1A9b9   Phillip   Summers  Female       bethany14@example.com
# 1  DbeAb8CcdfeFC2c  Kristine    Travis    Male       bthompson@example.com
# 2  A31Bee3c201ef58   Yesenia  Martinez    Male   kaitlinkaiser@example.com
# 3  1bA7A3dc874da3c      Lori      Todd    Male  buchananmanuel@example.net
#
#   001-084-906-7849x73518 10/26/1945     Games developer
# 0      214.112.6044x4913  3/24/1910      Phytotherapist
# 1           277.609.7938   7/2/1992           Homeopath
# 2           584.094.6111   8/3/2017   Market researcher
# 3      689-207-3558x7233  12/1/1938  Veterinary surgeon

# %%
# add header to tsv data

# %%
tsvdata = pd.read_table('E:/Python/MyPython/PycharmProjects/MyLearnings1/ETLQASession/TestFiles/04_people_tab.txt', header = None)

# %%
tsvdata
# Out:
#                  0         1         2       3                           4  \
# 0  88F7B33d2bcf9f5    Shelby   Terrell    Male        elijah57@example.net
# 1  f90cD3E76f1A9b9   Phillip   Summers  Female       bethany14@example.com
# 2  DbeAb8CcdfeFC2c  Kristine    Travis    Male       bthompson@example.com
# 3  A31Bee3c201ef58   Yesenia  Martinez    Male   kaitlinkaiser@example.com
# 4  1bA7A3dc874da3c      Lori      Todd    Male  buchananmanuel@example.net
#
#                         5           6                   7
# 0  001-084-906-7849x73518  10/26/1945     Games developer
# 1       214.112.6044x4913   3/24/1910      Phytotherapist
# 2            277.609.7938    7/2/1992           Homeopath
# 3            584.094.6111    8/3/2017   Market researcher
# 4       689-207-3558x7233   12/1/1938  Veterinary surgeon

# %%
# add custome columns for header

# %%
cols = ['Id','First','Last','Gender','Email','Phone','DOB','JObTitle']
tsvdata = pd.read_table('E:/Python/MyPython/PycharmProjects/MyLearnings1/ETLQASession/TestFiles/04_people_tab.txt', header = None, names = cols )

# %%
tsvdata
# Out:
#                 Id     First      Last  Gender                       Email  \
# 0  88F7B33d2bcf9f5    Shelby   Terrell    Male        elijah57@example.net
# 1  f90cD3E76f1A9b9   Phillip   Summers  Female       bethany14@example.com
# 2  DbeAb8CcdfeFC2c  Kristine    Travis    Male       bthompson@example.com
# 3  A31Bee3c201ef58   Yesenia  Martinez    Male   kaitlinkaiser@example.com
# 4  1bA7A3dc874da3c      Lori      Todd    Male  buchananmanuel@example.net
#
#                     Phone         DOB            JObTitle
# 0  001-084-906-7849x73518  10/26/1945     Games developer
# 1       214.112.6044x4913   3/24/1910      Phytotherapist
# 2            277.609.7938    7/2/1992           Homeopath
# 3            584.094.6111    8/3/2017   Market researcher
# 4       689-207-3558x7233   12/1/1938  Veterinary surgeon
